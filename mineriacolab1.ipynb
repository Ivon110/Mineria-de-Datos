# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivon110/Mineria-de-Datos/blob/main/mineriacolab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mineria de Datos

# %% [markdown]
# ##**Primer Parcial**

# %% [markdown]
# ### Introducción

# %% [markdown]
# ####Conceptos

# %% [markdown]
# La minería de datos es el proceso de extraer información útil a partir de una acumulación de datos, a menudo provenientes de un almacén o de una recopilación de data sets vinculados. Las herramientas para minería de datos incluyen potentes capacidades estadísticas, matemáticas y analíticas cuyo propósito principal es examinar grandes data sets para identificar tendencias, patrones y relaciones a fin de dar soporte a la toma de decisiones y planificación fundamentadas.

# %% [markdown]
# #### Ciencia de Datos

# %% [markdown]
# Libro

# %% [markdown]
# La ciencia de datos es un campo interdisciplinario que combina matemáticas, estadística, programación, inteligencia artificial (IA) y aprendizaje automático (machine learning) para analizar grandes volúmenes de datos estructurados y no estructurados. Su objetivo principal es extraer información valiosa que permita tomar decisiones estratégicas y resolver problemas empresariales.

# %% [markdown]
# IPython Magix Commands

# %%
# El comando magico %timeit sirve para evaluar el desempeño, en terminos de tiempo
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 118 µs ± 39.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#El comando magico %%timeit sirve para evaluar el desempeño, en terminos de tiempo
# Solo que este abarca varias lineas de codigo
# %%timeit
L = []
for n in range(1000):
  L.append(n ** 2)
# Out:
# 79.2 µs ± 2.01 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit?

# %%
# %%timeit?

# %% [markdown]
# IPython and Shell Commands

# %%
# !ls
# Out:
# sample_data

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# !cat README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
#Para ver las variables de entorno/ambiente
# %env
# Out:
# {'SHELL': '/bin/bash',
#  'COLAB_JUPYTER_TRANSPORT': 'ipc',
#  'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events',
#  'VM_GCE_METADATA_HOST': '169.254.169.253',
#  'MODEL_PROXY_HOST': 'https://mp.kaggle.net',
#  'HOSTNAME': '8dd22b69d4bd',
#  'LANGUAGE': 'en_US',
#  'TBE_RUNTIME_ADDR': '172.28.0.1:8011',
#  'GCE_METADATA_TIMEOUT': '3',
#  'COLAB_JUPYTER_IP': '172.28.0.12',
#  'COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL': 'http://172.28.0.1:8013/',
#  'KMP_LISTEN_PORT': '6000',
#  'TF_FORCE_GPU_ALLOW_GROWTH': 'true',
#  'ENV': '/root/.bashrc',
#  'PWD': '/',
#  'TBE_EPHEM_CREDS_ADDR': '172.28.0.1:8009',
#  'COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT': '30s',
#  'TBE_CREDS_ADDR': '172.28.0.1:8008',
#  'COLAB_JUPYTER_TOKEN': '<hidden>',
#  'LAST_FORCED_REBUILD': '20250623',
#  'TCLLIBPATH': '/usr/share/tcltk/tcllib1.20',
#  'COLAB_KERNEL_MANAGER_PROXY_HOST': '172.28.0.12',
#  'UV_BUILD_CONSTRAINT': '',
#  'COLAB_WARMUP_DEFAULTS': '1',
#  'HOME': '/root',
#  'LANG': 'en_US.UTF-8',
#  'CLOUDSDK_CONFIG': '/content/.config',
#  'UV_SYSTEM_PYTHON': 'true',
#  'COLAB_RELEASE_TAG': 'release-colab-external_20260120-060051_RC00',
#  'KMP_TARGET_PORT': '9000',
#  'KMP_EXTRA_ARGS': '--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-tdu9stmib4jq --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true ',
#  'UV_INSTALL_DIR': '/usr/local/bin',
#  'COLAB_LANGUAGE_SERVER_PROXY_LSP_DIRS': '/datalab/web/pyright/typeshed-fallback/stdlib,/usr/local/lib/python3.10/dist-packages',
#  'COLAB_KERNEL_MANAGER_PROXY_PORT': '6000',
#  'CLOUDSDK_PYTHON': 'python3',
#  'NO_GCE_CHECK': 'False',
#  'PYTHONPATH': '/env/python',
#  'SHLVL': '0',
#  'COLAB_LANGUAGE_SERVER_PROXY': '/usr/colab/bin/language_service',
#  'UV_CONSTRAINT': '',
#  'PYTHONUTF8': '1',
#  'COLAB_GPU': '',
#  'GCS_READ_CACHE_BLOCK_SIZE_MB': '16',
#  'LC_ALL': 'en_US.UTF-8',
#  'COLAB_FILE_HANDLER_ADDR': 'localhost:3453',
#  'PATH': '/opt/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin',
#  'COLAB_IMAGE_TYPE': 'cpu',
#  'COLAB_DEBUG_ADAPTER_MUX_PATH': '/usr/local/bin/dap_multiplexer',
#  'PYTHONWARNINGS': 'ignore:::pip._internal.cli.base_command',
#  'DEBIAN_FRONTEND': 'noninteractive',
#  'COLAB_BACKEND_VERSION': 'next',
#  'OLDPWD': '/',
#  '_PYVIZ_COMMS_INSTALLED': '1',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'JPY_SESSION_NAME': '1_DoZdhI8hJheicZQvuWX09T916JD9BEN',
#  'JPY_PARENT_PID': '92',
#  'TERM': 'xterm-color',
#  'CLICOLOR': '1',
#  'PAGER': 'cat',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#  'ENABLE_DIRECTORYPREFETCHER': '1',
#  'USE_AUTH_EPHEM': '1',
#  'COLAB_NOTEBOOK_ID': '1_DoZdhI8hJheicZQvuWX09T916JD9BEN'}

# %% [markdown]
# Undestanding Data Types In Python

# %%
import numpy as np

# %%
np.array([1,4,2,5,3])
# Out:
# array([1, 4, 2, 5, 3])

# %%
np.array([3.14,4,2,3])
# Out:
# array([3.14, 4.  , 2.  , 3.  ])

# %%
#float 32 para la precision del flotante
np.array([1,2,3,4], dtype='float32')
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %%
np.array([1,2,3,4], dtype='int')
# Out:
# array([1, 2, 3, 4])

# %%
np.array([range(i, i + 3) for i in [2,4,6]])
# Out:
# array([[2, 3, 4],
#        [4, 5, 6],
#        [6, 7, 8]])

# %% [markdown]
# The Basics of NumPy Arrays

# %%
#Importamos NumPy
import numpy as np

# %%
#Generamos una semilla aleatoria
np.random.seed(0)
# Generamos un arreglo aleatorio de enteros, de tamaño seis
x1 = np.random.randint(10, size=6) #El superior no se toma en cuenta es decir va del 0 al 9
# Generamos un arreglo aleatorio de enteros, de tamaño tres renglones y cuatro columnas
x2 = np.random.randint(10, size=(3,4))
# Para hacer un arreglo tridimensional
x3 = np.random.randint(10, size=(3,4,5))

# %%
print("x3 ndim: ", x3.ndim) # ndim nos dice el numero de dimensiones (x3 tiene 3 dimensiones)
print("x3 shape:", x3.shape) # shape imprime su forma, regresa lo que contiene la lista
print("x3 size: ", x3.size) # size es la multiplicacion del shape 3x4=12 x 5 = 60
# Out:
# x3 ndim:  3
# x3 shape: (3, 4, 5)
# x3 size:  60

# %%
print(x2.dtype) # dtype nos dice el tamaño en bytes de cada arreglo
# Out:
# int64

# %%
#itemsize: Lista el tamaño (en bytes) de cada arreglo
print("itemsize:", x3.itemsize, "bytes")
# nbytes: Lista el tamaño total (en bytes) del arreglo
print("nbytes:", x3.nbytes, "bytes")
# Out:
# itemsize: 8 bytes
# nbytes: 480 bytes

# %%
# Son digitos entre el 0 y 10 porque le dimos este limite desde el principio (x1 = np.random.randint(10, size=6) )

x1
# Out:
# array([5, 0, 3, 3, 7, 9])

# %%
#Colocamos el índice del elemento a extraer, en este caso el primer elemento tiene el índice 0
x1[0]
# Out:
# np.int64(5)

# %%
#Colocamos el índice del elemento a extraer, en este caso el quinto elemento tiene el índice 4
x1[4]
# Out:
# np.int64(7)

# %%
# Si queremos el ultimo elemento de ndarray (Arreglo de n dimensiones) podemos poner -1 de índice
x1[-1]
# Out:
# np.int64(9)

# %%
#Array Multidimensional
x2
# Out:
# array([[3, 5, 2, 4],
#        [7, 6, 8, 8],
#        [1, 6, 7, 7]])

# %%
#Colocamos el índice del elemento a extraer, en este caso el primer elemento tiene el índice 0,0 para un indice multidimensional
x2[0,0]
# Out:
# np.int64(3)

# %%
# Renglon es la fila
# Renglon,Columna
x2[0,2]
# Out:
# np.int64(2)

# %%
x2[0,0] = 12 # Asignar un nuevo valor al renglon 0 columna 0
x2
# Out:
# array([[12,  5,  2,  4],
#        [ 7,  6,  8,  8],
#        [ 1, 12,  7,  7]])

# %% [markdown]
# #### Estadística Básica

# %% [markdown]
# Media (Mean)

# %%
# Uso de la Media
data = np.array([1, 2, 3, 4, 5])
media = np.mean(data)
print(media)
# Out:
# 3.0

# %% [markdown]
# Promedio (Average) y Promedio Ponderado

# %%
data = np.array([1, 2, 3, 4, 5])
weights = np.array([1, 2, 3, 4, 5])
promedio = np.average(data)
promedio_ponderado = np.average(data, weights=weights)

# %%
print(promedio)
print(promedio_ponderado) #Para darle un peso distinto a cada elemento
# Out:
# 3.0
# 3.6666666666666665

# %% [markdown]
# Mediana

# %%
# Elemento de en medio
# No es sensible a datos aberrantes
mediana = np.median(data)

# %% [markdown]
# Medidas de Dispersion

# %% [markdown]
# *   Varianza y Desviación Estándar

# %%
varianza = np.var(data)
desviacion = np.std(data)

# %% [markdown]
# Generación de Datos Aleatorios

# %%
muestra = np.random.normal(0, 1, 1000)
print(np.mean(muestra), np.std(muestra)) # Usamos medida de tendencia central que es la media y una Medida de Dispersion que es la desviacion
# Out:
# -0.006543456960417206 1.0059985778093545

# %% [markdown]
# Correlación

# %%
# Nos dice que tan relacionados estan dos o mas variables
# Entre mas se acerque a uno es una relacion fuerte, nos importan los extremos que son para ver el coeficiente de relacion
corr = np.corrcoef([1,2,3], [1,5,7])

# %% [markdown]
# Cuadros Estadísticos

# %%
import numpy as np
import pandas as pd
from io import StringIO

raw = """Marca temporal\tNúmero de matrícula\t¿Cuántos años cumplidos tienes?\t¿Has realizado programas utilizando Python?\t¿Has utilizado Google Colab?\t¿Tienes cuenta de GitHub?
19/01/2026 18:32:18\t178920\t22\tSi\tNo\tSi
19/01/2026 18:32:23\t182712\t21\tSi\tNo\tSi
19/01/2026 18:32:25\t180370\t26\tSi\tSi\tSi
19/01/2026 18:32:27\t182570\t21\tSi\tSi\tSi
19/01/2026 18:32:28\t177622\t24\tSi\tNo\tSi
19/01/2026 18:32:29\t175166\t22\tSi\tSi\tSi
19/01/2026 18:32:30\t177573\t22\tSi\tSi\tSi
19/01/2026 18:32:35\t178430\t21\tSi\tSi\tSi
19/01/2026 18:32:38\t179169\t23\tSi\tNo\tSi
19/01/2026 18:32:41\t177263\t22\tSi\tSi\tSi
19/01/2026 18:32:48\t179884\t23\tSi\tNo\tSi
19/01/2026 18:32:48\t183016\t22\tSi\tNo\tSi
19/01/2026 18:32:50\t179033\t23\tSi\tSi\tNo
19/01/2026 18:32:54\t178218\t22\tSi\tNo\tSi
19/01/2026 18:32:55\t178446\t22\tSi\tSi\tSi
19/01/2026 18:33:00\t178166\t22\tSi\tSi\tNo
19/01/2026 18:33:02\t177406\t22\tSi\tNo\tSi
19/01/2026 18:33:05\t177192\t22\tSi\tSi\tSi
19/01/2026 18:33:08\t182451\t21\tSi\tNo\tSi
19/01/2026 18:33:08\t171513\t24\tNo\tNo\tSi
19/01/2026 18:33:09\t181619\t21\tSi\tNo\tSi
19/01/2026 18:33:12\t182298\t23\tSi\tNo\tSi
19/01/2026 18:33:14\t181419\t24\tNo\tNo\tSi
19/01/2026 18:33:32\t177291\t21\tSi\tSi\tSi
19/01/2026 18:33:42\t182085\t22\tSi\tNo\tSi
19/01/2026 18:33:53\t176453\t22\tSi\tNo\tSi
19/01/2026 18:34:04\t176263\t24\tSi\tNo\tSi
19/01/2026 18:34:06\t179997\t21\tSi\tNo\tSi
19/01/2026 18:36:21\t175842\t23\tSi\tNo\tNo
19/01/2026 20:19:21\t179913\t20\tSi\tNo\tSi
19/01/2026 20:19:48\t177301\t22\tSi\tSi\tNo
19/01/2026 20:20:06\t183060\t21\tSi\tNo\tSi
19/01/2026 20:20:08\t177935\t22\tSi\tSi\tSi
19/01/2026 20:20:19\t177700\t20\tSi\tSi\tSi
19/01/2026 20:20:26\t178318\t24\tSi\tSi\tSi
19/01/2026 20:20:27\t174653\t24\tSi\tNo\tSi
19/01/2026 20:20:29\t177139\t21\tSi\tNo\tSi
19/01/2026 20:20:31\t173479\t25\tSi\tNo\tNo
19/01/2026 20:20:39\t175588\t23\tNo\tNo\tSi
19/01/2026 20:20:45\t178774\t23\tSi\tSi\tSi
19/01/2026 20:20:45\t175031\t23\tSi\tNo\tNo
19/01/2026 20:20:49\t178396\t21\tSi\tSi\tSi
19/01/2026 20:20:49\t172068\t23\tNo\tNo\tNo
19/01/2026 20:20:50\t174197\t23\tNo\tNo\tSi
19/01/2026 20:20:55\t178584\t22\tSi\tNo\tSi
19/01/2026 20:20:55\t175329\t24\tSi\tNo\tSi
19/01/2026 20:20:56\t177685\t22\tSi\tSi\tSi
19/01/2026 20:20:57\t178678\t22\tNo\tNo\tSi
19/01/2026 20:21:04\t177143\t22\tSi\tNo\tSi
19/01/2026 20:21:07\t182318\t26\tSi\tNo\tSi
19/01/2026 20:21:27\t182377\t20\tSi\tNo\tSi
19/01/2026 20:21:34\t179419\t22\tSi\tNo\tNo
19/01/2026 20:21:35\t181662\t21\tSi\tNo\tSi
19/01/2026 20:21:38\t181760\t21\tSi\tNo\tSi
19/01/2026 20:22:06\t177888\t22\tSi\tNo\tSi
19/01/2026 20:22:15\t176535\t25\tSi\tNo\tSi
19/01/2026 20:22:29\t179862\t21\tSi\tNo\tSi
19/01/2026 20:22:32\t178378\t22\tSi\tNo\tSi
19/01/2026 20:22:50\t177451\t22\tSi\tNo\tSi
19/01/2026 20:23:15\t179804\t21\tSi\tNo\tSi
"""

# Cargar datos
df = pd.read_csv(StringIO(raw), sep='\t')
df.columns = [c.strip() for c in df.columns]

# Variables
df['edad'] = pd.to_numeric(df['¿Cuántos años cumplidos tienes?'], errors='coerce') #coerce - Ignora
map_sn = {'Si': True, 'No': False}
df['prog_python'] = df['¿Has realizado programas utilizando Python?'].map(map_sn)
df['usa_colab'] = df['¿Has utilizado Google Colab?'].map(map_sn)
df['cuenta_github'] = df['¿Tienes cuenta de GitHub?'].map(map_sn)

# %%
df.head()
# Out:
#         Marca temporal  Número de matrícula  ¿Cuántos años cumplidos tienes?  \
# 0  19/01/2026 18:32:18               178920                               22
# 1  19/01/2026 18:32:23               182712                               21
# 2  19/01/2026 18:32:25               180370                               26
# 3  19/01/2026 18:32:27               182570                               21
# 4  19/01/2026 18:32:28               177622                               24
#
#   ¿Has realizado programas utilizando Python? ¿Has utilizado Google Colab?  \
# 0                                          Si                           No
# 1                                          Si                           No
# 2                                          Si                           Si
# 3                                          Si                           Si
# 4                                          Si                           No
#
#   ¿Tienes cuenta de GitHub?  edad  prog_python  usa_colab  cuenta_github
# 0                        Si    22         True      False           True
# 1                        Si    21         True      False           True
# 2                        Si    26         True       True           True
# 3                        Si    21         True       True           True
# 4                        Si    24         True      False           True

# %%
# A NumPy
edad = df['edad'].to_numpy(dtype=float) #Toda la columna la mete a arreglo de NumPy
prog_py = df['prog_python'].to_numpy(dtype=bool)
usa_colab = df['usa_colab'].to_numpy(dtype=bool)
cuenta_gh = df['cuenta_github'].to_numpy(dtype=bool)

# %%
#:5 desde el principio hasta hasta el 5 (:)
edad[:5]
# Out:
# array([22., 21., 26., 21., 24.])

# %%
prog_py[:5]
# Out:
# array([ True,  True,  True,  True,  True])

# %%
# Descriptivos de edad (NumPy)
summary_age = {
    'n': int(edad.size),
    'min': float(np.min(edad)), # Para el valor minimo
    'p25': float(np.percentile(edad, 25)), #percentile genera intervalos para traer un porcentaje del totaal (Toma tanto porcentaje datos)
    'mediana': float(np.median(edad)), # Elemento de en medio - Medida Tend Central
    'media': float(np.mean(edad)), #promedio - Medida Tend Central
    'p75': float(np.percentile(edad, 75)), #75% de los datos donde se ubican los datos
    'max': float(np.max(edad)), #Edad maximma
    'rango(ptp)': float(np.ptp(edad)), #ptp - pick to peak,, del minimo al maximo cual es el rango
    'var_muestral': float(np.var(edad, ddof=1)), # var es la variancia muestral, ddof - grado de libertad - Medida Disp
    'std_muestral': float(np.std(edad, ddof=1)),# Desviacion - Medida Disp
    'cv': float(np.std(edad, ddof=1)/np.mean(edad)), #Desviacion central/media
}

# %%
summary_age
# Out:
# {'n': 60,
#  'min': 20.0,
#  'p25': 21.0,
#  'mediana': 22.0,
#  'media': 22.3,
#  'p75': 23.0,
#  'max': 26.0,
#  'rango(ptp)': 6.0,
#  'var_muestral': 1.8406779661016948,
#  'std_muestral': 1.3567158752302173,
#  'cv': 0.06083927691615324}

# %%
# Frecuencias (Cant de elementos) (NumPy)
# Creamos diccionarios
freq_python = {'Si': int(np.count_nonzero(prog_py)), 'No': int(edad.size - np.count_nonzero(prog_py))}
freq_colab  = {'Si': int(np.count_nonzero(usa_colab)), 'No': int(edad.size - np.count_nonzero(usa_colab))}
freq_gh     = {'Si': int(np.count_nonzero(cuenta_gh)), 'No': int(edad.size - np.count_nonzero(cuenta_gh))}

# %%
print (f"Alumnos que han utilizado de Python: {freq_python}")
print (f"Alumnos que han utilizado de Colab: {freq_colab}")
print (f"Alumnos que han utilizado de GitHub: {freq_gh}")
# Out:
# Alumnos que han utilizado de Python: {'Si': 54, 'No': 6}
# Alumnos que han utilizado de Colab: {'Si': 18, 'No': 42}
# Alumnos que han utilizado de GitHub: {'Si': 52, 'No': 8}

# %%
# Tablas cruzadas (NumPy)
def tabla2x2(a, b):
    t = np.zeros((2,2), dtype=int) #np.zeros: Genera una matriz de 2 renglones y columnas rellenas de ceros
    t[1,1] = np.count_nonzero(a & b) #count_nonzero: Asigna la cuenta de los que no son 0
    t[1,0] = np.count_nonzero(a & ~b)
    t[0,1] = np.count_nonzero(~a & b)
    t[0,0] = np.count_nonzero(~a & ~b)
    return t

# Hace la multiplicacion boolean
tab_py_colab = tabla2x2(prog_py, usa_colab)
tab_py_gh    = tabla2x2(prog_py, cuenta_gh)
tab_colab_gh = tabla2x2(usa_colab, cuenta_gh)

# %%
print(f"Tabla Cruzada 2x2 de Python y Colab: \n{tab_py_colab}")
# Out:
# Tabla Cruzada 2x2 de Python y Colab:
# [[ 6  0]
#  [36 18]]

# %%
print(f"Tabla Cruzada 2x2 de Python y GitHub: \n{tab_py_gh}")
# Out:
# Tabla Cruzada 2x2 de Python y GitHub:
# [[ 1  5]
#  [ 7 47]]

# %%
# Medias de edad por grupo (NumPy)
means_by_group = {
    'edad_promedio_Python': {'Si': float(np.mean(edad[prog_py])) if np.any(prog_py) else np.nan,
                             'No': float(np.mean(edad[~prog_py])) if np.any(~prog_py) else np.nan},
    'edad_promedio_Colab':  {'Si': float(np.mean(edad[usa_colab])) if np.any(usa_colab) else np.nan,
                             'No': float(np.mean(edad[~usa_colab])) if np.any(~usa_colab) else np.nan},
    'edad_promedio_GitHub': {'Si': float(np.mean(edad[cuenta_gh])) if np.any(cuenta_gh) else np.nan,
                             'No': float(np.mean(edad[~cuenta_gh])) if np.any(~cuenta_gh) else np.nan},
}

summary_age, freq_python, freq_colab, freq_gh, tab_py_colab, tab_py_gh, tab_colab_gh, means_by_group
# Out:
# ({'n': 60,
#   'min': 20.0,
#   'p25': 21.0,
#   'mediana': 22.0,
#   'media': 22.3,
#   'p75': 23.0,
#   'max': 26.0,
#   'rango(ptp)': 6.0,
#   'var_muestral': 1.8406779661016948,
#   'std_muestral': 1.3567158752302173,
#   'cv': 0.06083927691615324},
#  {'Si': 54, 'No': 6},
#  {'Si': 18, 'No': 42},
#  {'Si': 52, 'No': 8},
#  array([[ 6,  0],
#         [36, 18]]),
#  array([[ 1,  5],
#         [ 7, 47]]),
#  array([[ 5, 37],
#         [ 3, 15]]),
#  {'edad_promedio_Python': {'Si': 22.203703703703702, 'No': 23.166666666666668},
#   'edad_promedio_Colab': {'Si': 22.11111111111111, 'No': 22.38095238095238},
#   'edad_promedio_GitHub': {'Si': 22.21153846153846, 'No': 22.875}})

# %%
#Subir el texto en bloc de notas , quitar \t por comas  - eliminar stringIO
df = pd.read_csv("NombreArchibo")#Por comas
raw = """Marca temporal\tNúmero de matrícula\t¿Cuántos años cumplidos tienes?\t¿Has realizado programas utilizando Python?\t¿Has utilizado Google Colab?\t¿Tienes cuenta de GitHub?
19/01/2026 18:32:18\t178920\t22\tSi\tNo\tSi
19/01/2026 18:32:23\t182712\t21\tSi\tNo\tSi
19/01/2026 18:32:25\t180370\t26\tSi\tSi\tSi
19/01/2026 18:32:27\t182570\t21\tSi\tSi\tSi
19/01/2026 18:32:28\t177622\t24\tSi\tNo\tSi
19/01/2026 18:32:29\t175166\t22\tSi\tSi\tSi
19/01/2026 18:32:30\t177573\t22\tSi\tSi\tSi
19/01/2026 18:32:35\t178430\t21\tSi\tSi\tSi
19/01/2026 18:32:38\t179169\t23\tSi\tNo\tSi
19/01/2026 18:32:41\t177263\t22\tSi\tSi\tSi
19/01/2026 18:32:48\t179884\t23\tSi\tNo\tSi
19/01/2026 18:32:48\t183016\t22\tSi\tNo\tSi
19/01/2026 18:32:50\t179033\t23\tSi\tSi\tNo
19/01/2026 18:32:54\t178218\t22\tSi\tNo\tSi
19/01/2026 18:32:55\t178446\t22\tSi\tSi\tSi
19/01/2026 18:33:00\t178166\t22\tSi\tSi\tNo
19/01/2026 18:33:02\t177406\t22\tSi\tNo\tSi
19/01/2026 18:33:05\t177192\t22\tSi\tSi\tSi
19/01/2026 18:33:08\t182451\t21\tSi\tNo\tSi
19/01/2026 18:33:08\t171513\t24\tNo\tNo\tSi
19/01/2026 18:33:09\t181619\t21\tSi\tNo\tSi
19/01/2026 18:33:12\t182298\t23\tSi\tNo\tSi
19/01/2026 18:33:14\t181419\t24\tNo\tNo\tSi
19/01/2026 18:33:32\t177291\t21\tSi\tSi\tSi
19/01/2026 18:33:42\t182085\t22\tSi\tNo\tSi
19/01/2026 18:33:53\t176453\t22\tSi\tNo\tSi
19/01/2026 18:34:04\t176263\t24\tSi\tNo\tSi
19/01/2026 18:34:06\t179997\t21\tSi\tNo\tSi
19/01/2026 18:36:21\t175842\t23\tSi\tNo\tNo
19/01/2026 20:19:21\t179913\t20\tSi\tNo\tSi
19/01/2026 20:19:48\t177301\t22\tSi\tSi\tNo
19/01/2026 20:20:06\t183060\t21\tSi\tNo\tSi
19/01/2026 20:20:08\t177935\t22\tSi\tSi\tSi
19/01/2026 20:20:19\t177700\t20\tSi\tSi\tSi
19/01/2026 20:20:26\t178318\t24\tSi\tSi\tSi
19/01/2026 20:20:27\t174653\t24\tSi\tNo\tSi
19/01/2026 20:20:29\t177139\t21\tSi\tNo\tSi
19/01/2026 20:20:31\t173479\t25\tSi\tNo\tNo
19/01/2026 20:20:39\t175588\t23\tNo\tNo\tSi
19/01/2026 20:20:45\t178774\t23\tSi\tSi\tSi
19/01/2026 20:20:45\t175031\t23\tSi\tNo\tNo
19/01/2026 20:20:49\t178396\t21\tSi\tSi\tSi
19/01/2026 20:20:49\t172068\t23\tNo\tNo\tNo
19/01/2026 20:20:50\t174197\t23\tNo\tNo\tSi
19/01/2026 20:20:55\t178584\t22\tSi\tNo\tSi
19/01/2026 20:20:55\t175329\t24\tSi\tNo\tSi
19/01/2026 20:20:56\t177685\t22\tSi\tSi\tSi
19/01/2026 20:20:57\t178678\t22\tNo\tNo\tSi
19/01/2026 20:21:04\t177143\t22\tSi\tNo\tSi
19/01/2026 20:21:07\t182318\t26\tSi\tNo\tSi
19/01/2026 20:21:27\t182377\t20\tSi\tNo\tSi
19/01/2026 20:21:34\t179419\t22\tSi\tNo\tNo
19/01/2026 20:21:35\t181662\t21\tSi\tNo\tSi
19/01/2026 20:21:38\t181760\t21\tSi\tNo\tSi
19/01/2026 20:22:06\t177888\t22\tSi\tNo\tSi
19/01/2026 20:22:15\t176535\t25\tSi\tNo\tSi
19/01/2026 20:22:29\t179862\t21\tSi\tNo\tSi
19/01/2026 20:22:32\t178378\t22\tSi\tNo\tSi
19/01/2026 20:22:50\t177451\t22\tSi\tNo\tSi
19/01/2026 20:23:15\t179804\t21\tSi\tNo\tSi
"""
raw = raw.repla
